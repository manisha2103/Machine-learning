# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\churn_dataset.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
del df['customerID']

# %%
df['TotalCharges']=df['TotalCharges'].apply(lambda x:x.replace(' ','0'))

# %%
df[['TotalCharges']]=df[['TotalCharges']].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## identifying input and output variables

# %% [markdown]
# ## the output variable is churn which is available in historical data

# %% [markdown]
# ## it will come under supervised learning and classification task must be performed

# %% [markdown]
# ## evaluation metric to be performed will be accuracy score

# %%
X=df[['gender','SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService',
'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','MonthlyCharges' ,     
'TotalCharges']]
y=df['Churn']

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineBackup DeviceProtection TechSupport  \
# 0  No phone service             DSL          Yes               No          No
# 1                No             DSL           No              Yes          No
# 2                No             DSL          Yes               No          No
# 3  No phone service             DSL           No              Yes         Yes
# 4                No     Fiber optic           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %% [markdown]
# ## splitting the dataset into training and testing using 75:25 split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=0)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (5282, 18) (5282,)
# (1761, 18) (1761,)

# %%
X_train.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3296  Female              0      No         No      24          Yes
# 6397    Male              1      No         No      54          Yes
# 6043    Male              0      No         No       3           No
# 5309  Female              0     Yes         No      61          Yes
# 3000    Male              0      No         No      12          Yes
#
#          MultipleLines InternetService         OnlineBackup  \
# 3296                No             DSL                   No
# 6397                No             DSL                   No
# 6043  No phone service             DSL                   No
# 5309                No              No  No internet service
# 3000               Yes     Fiber optic                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3296                  Yes                   No                   No
# ...

# %% [markdown]
# ## separating categorical and numerical data in the train data

# %%
X_train_cat=X_train.select_dtypes(include=['object'])
X_train_cat
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 3296  Female      No         No          Yes                No
# 6397    Male      No         No          Yes                No
# 6043    Male      No         No           No  No phone service
# 5309  Female     Yes         No          Yes                No
# 3000    Male      No         No          Yes               Yes
# ...      ...     ...        ...          ...               ...
# 4931    Male     Yes         No          Yes               Yes
# 3264  Female      No        Yes          Yes                No
# 1653    Male     Yes         No          Yes                No
# 2607    Male      No         No          Yes                No
# 2732  Female      No        Yes          Yes                No
#
#      InternetService         OnlineBackup     DeviceProtection  \
# 3296             DSL                   No                  Yes
# 6397             DSL                   No                  Yes
# ...

# %%
X_train_num=X_train.select_dtypes(include=['int64','float64'])
X_train_num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 3296              0      24           49.30       1233.25
# 6397              1      54           65.25       3529.95
# 6043              0       3           40.15        130.75
# 5309              0      61           20.25       1278.80
# 3000              0      12           84.45       1059.55
# ...             ...     ...             ...           ...
# 4931              0      15          103.45       1539.80
# 3264              0      10           91.10        964.35
# 1653              0      58           20.75       1185.95
# 2607              1       1           69.75         69.75
# 2732              0       4           20.40         94.50
#
# [5282 rows x 4 columns]

# %%
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 3296              0      24           49.30       1233.25
# 6397              1      54           65.25       3529.95
# 6043              0       3           40.15        130.75
# 5309              0      61           20.25       1278.80
# 3000              0      12           84.45       1059.55

# %% [markdown]
# ## rescaling the numerical data i.e applying standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_num_transformed=pd.DataFrame(scaler.fit_transform(X_train_num),columns=X_train_num.columns,index=X_train_num.index)
X_train_num_transformed
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 3296      -0.435476 -0.340191       -0.514314     -0.460284
# 6397       2.296336  0.883210        0.017840      0.556508
# 6043      -0.435476 -1.196572       -0.819594     -0.948382
# 5309      -0.435476  1.168670       -1.483535     -0.440119
# 3000      -0.435476 -0.829552        0.658427     -0.537185
# ...             ...       ...             ...           ...
# 4931      -0.435476 -0.707212        1.292341     -0.324569
# 3264      -0.435476 -0.911112        0.880297     -0.579332
# 1653      -0.435476  1.046330       -1.466853     -0.481225
# 2607       2.296336 -1.278132        0.167978     -0.975388
# 2732      -0.435476 -1.155792       -1.478531     -0.964431
#
# [5282 rows x 4 columns]

# %%
X_train_num_transformed.describe()
# Out:
#        SeniorCitizen        tenure  MonthlyCharges  TotalCharges
# count   5.282000e+03  5.282000e+03    5.282000e+03  5.282000e+03
# mean   -5.258846e-16 -1.107701e-16   -3.584158e-16 -3.840169e-17
# std     1.000095e+00  1.000095e+00    1.000095e+00  1.000095e+00
# min    -4.354763e-01 -1.318912e+00   -1.550263e+00 -1.006268e+00
# 25%    -4.354763e-01 -9.518918e-01   -9.663949e-01 -8.258984e-01
# 50%    -4.354763e-01 -1.362912e-01    1.863278e-01 -3.879773e-01
# 75%    -4.354763e-01  9.239896e-01    8.369237e-01  6.627499e-01
# max     2.296336e+00  1.617250e+00    1.799472e+00  2.838659e+00

# %%
print("Number of Numerical Features:", scaler.n_features_in_)
print("Mean of each column:", scaler.mean_)
print("Std of each column:", np.sqrt(scaler.var_))
# Out:
# Number of Numerical Features: 4
# Mean of each column: [1.59409315e-01 3.23421053e+01 6.47152878e+01 2.27292614e+03]
# Std of each column: [3.66057352e-01 2.45218061e+01 2.99725187e+01 2.25876892e+03]

# %% [markdown]
# ## categorical train data

# %%
X_train_cat['gender'].value_counts(normalize=True)
# Out:
# Female    0.502272
# Male      0.497728
# Name: gender, dtype: float64

# %%
X_train_cat['Partner'].value_counts(normalize=True)
# Out:
# No     0.515524
# Yes    0.484476
# Name: Partner, dtype: float64

# %%
X_train_cat['Dependents'].value_counts(normalize=True)
# Out:
# No     0.698788
# Yes    0.301212
# Name: Dependents, dtype: float64

# %%
X_train_cat['PhoneService'].value_counts(normalize=True)
# Out:
# Yes    0.904014
# No     0.095986
# Name: PhoneService, dtype: float64

# %%
X_train_cat['MultipleLines'].value_counts(normalize=True)
# Out:
# No                  0.482772
# Yes                 0.421242
# No phone service    0.095986
# Name: MultipleLines, dtype: float64

# %%
X_train_cat['InternetService'].value_counts(normalize=True)
# Out:
# Fiber optic    0.439606
# DSL            0.343809
# No             0.216585
# Name: InternetService, dtype: float64

# %%
X_train_cat['OnlineBackup'].value_counts(normalize=True)
# Out:
# No                     0.439228
# Yes                    0.344188
# No internet service    0.216585
# Name: OnlineBackup, dtype: float64

# %%
X_train_cat['DeviceProtection'].value_counts(normalize=True)
# Out:
# No                     0.441499
# Yes                    0.341916
# No internet service    0.216585
# Name: DeviceProtection, dtype: float64

# %%
X_train_cat['TechSupport'].value_counts(normalize=True)
# Out:
# No                     0.498107
# Yes                    0.285309
# No internet service    0.216585
# Name: TechSupport, dtype: float64

# %%
X_train_cat['StreamingTV'].value_counts(normalize=True)
# Out:
# No                     0.400606
# Yes                    0.382810
# No internet service    0.216585
# Name: StreamingTV, dtype: float64

# %%
X_train_cat['StreamingMovies'].value_counts(normalize=True)
# Out:
# No                     0.397009
# Yes                    0.386407
# No internet service    0.216585
# Name: StreamingMovies, dtype: float64

# %%
X_train_cat['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.553200
# Two year          0.235706
# One year          0.211094
# Name: Contract, dtype: float64

# %%
X_train_cat['PaperlessBilling'].value_counts(normalize=True)
# Out:
# Yes    0.597501
# No     0.402499
# Name: PaperlessBilling, dtype: float64

# %%
X_train_cat['PaymentMethod'].value_counts(normalize=True)
# Out:
# Electronic check             0.334532
# Mailed check                 0.230973
# Bank transfer (automatic)    0.219992
# Credit card (automatic)      0.214502
# Name: PaymentMethod, dtype: float64

# %% [markdown]
# ## applying one hot encoding on categorical train data as data is of nominal

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names_out(X_train_cat.columns), 
                               index = X_train_cat.index)

X_train_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 3296          0.0          0.0             0.0               1.0
# 6397          1.0          0.0             0.0               1.0
# 6043          1.0          0.0             0.0               0.0
# 5309          0.0          1.0             0.0               1.0
# 3000          1.0          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 3296                             0.0                0.0
# 6397                             0.0                0.0
# 6043                             1.0                0.0
# 5309                             0.0                0.0
# 3000                             0.0                1.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 3296                          0.0                 0.0
# 6397                          0.0                 0.0
# 6043                          0.0                 0.0
# ...

# %% [markdown]
# ## concating the rescaled and encoded dataframes

# %%
X_train_transformed = pd.concat([X_train_num_transformed, X_train_cat_ohe], axis=1)

X_train_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 3296      -0.435476 -0.340191       -0.514314     -0.460284          0.0
# 6397       2.296336  0.883210        0.017840      0.556508          1.0
# 6043      -0.435476 -1.196572       -0.819594     -0.948382          1.0
# 5309      -0.435476  1.168670       -1.483535     -0.440119          0.0
# 3000      -0.435476 -0.829552        0.658427     -0.537185          1.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 3296          0.0             0.0               1.0
# 6397          0.0             0.0               1.0
# 6043          0.0             0.0               0.0
# 5309          1.0             0.0               1.0
# 3000          0.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 3296                             0.0                0.0  ...
# 6397                             0.0                0.0  ...
# ...

# %% [markdown]
# ## preparing the test data

# %%
X_test.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2200  Female              0      No         No      19          Yes
# 4627    Male              0      No         No      60          Yes
# 3225  Female              0      No         No      13          Yes
# 2828    Male              0      No         No       1          Yes
# 3768  Female              0     Yes         No      55          Yes
#
#      MultipleLines InternetService         OnlineBackup     DeviceProtection  \
# 2200            No             DSL                  Yes                   No
# 4627           Yes     Fiber optic                  Yes                  Yes
# 3225            No             DSL                   No                   No
# 2828            No              No  No internet service  No internet service
# 3768           Yes     Fiber optic                  Yes                   No
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1761 entries, 2200 to 450
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            1761 non-null   object
#  1   SeniorCitizen     1761 non-null   int64
#  2   Partner           1761 non-null   object
#  3   Dependents        1761 non-null   object
#  4   tenure            1761 non-null   int64
#  5   PhoneService      1761 non-null   object
#  6   MultipleLines     1761 non-null   object
#  7   InternetService   1761 non-null   object
#  8   OnlineBackup      1761 non-null   object
#  9   DeviceProtection  1761 non-null   object
#  10  TechSupport       1761 non-null   object
#  11  StreamingTV       1761 non-null   object
#  12  StreamingMovies   1761 non-null   object
#  13  Contract          1761 non-null   object
#  14  PaperlessBilling  1761 non-null   object
#  15  PaymentMethod     1761 non-null   object
# ...

# %% [markdown]
# ## separating the categorical and numerical columns of test data

# %%
X_test_cat=X_test.select_dtypes(include=['object'])
X_test_cat
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 2200  Female      No         No          Yes            No             DSL
# 4627    Male      No         No          Yes           Yes     Fiber optic
# 3225  Female      No         No          Yes            No             DSL
# 2828    Male      No         No          Yes            No              No
# 3768  Female     Yes         No          Yes           Yes     Fiber optic
# ...      ...     ...        ...          ...           ...             ...
# 3184  Female     Yes         No          Yes           Yes             DSL
# 2551  Female      No         No          Yes            No              No
# 5735  Female     Yes        Yes          Yes            No              No
# 5096    Male     Yes        Yes          Yes           Yes             DSL
# 450   Female      No         No          Yes           Yes              No
#
# ...

# %%
X_test_num=X_test.select_dtypes(include=['int64','float64'])
X_test_num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 2200              0      19           58.20       1045.25
# 4627              0      60          116.60       7049.50
# 3225              0      13           71.95        923.85
# 2828              0       1           20.45         20.45
# 3768              0      55           77.75       4266.40
# ...             ...     ...             ...           ...
# 3184              0      71           83.30       5894.50
# 2551              0      12           19.45        227.45
# 5735              0      48           20.00        935.90
# 5096              0      71           86.85       6263.80
# 450               0      64           24.70       1642.75
#
# [1761 rows x 4 columns]

# %% [markdown]
# ## applying one hot encoding on categorical test data

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

# column names are (annoyingly) lost after OneHotEncoding
# (i.e. the dataframe is converted to a numpy ndarray)

X_test_cat_ohe = pd.DataFrame(encoder.fit_transform(X_test_cat), 
                               columns=encoder.get_feature_names_out(X_test_cat.columns), 
                               index = X_test_cat.index)

X_test_cat_ohe.head()
# Out:
#       gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 2200          0.0          0.0             0.0               1.0
# 4627          1.0          0.0             0.0               1.0
# 3225          0.0          0.0             0.0               1.0
# 2828          1.0          0.0             0.0               1.0
# 3768          0.0          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  \
# 2200                             0.0                0.0
# 4627                             0.0                1.0
# 3225                             0.0                0.0
# 2828                             0.0                0.0
# 3768                             0.0                1.0
#
#       InternetService_Fiber optic  InternetService_No  \
# 2200                          0.0                 0.0
# 4627                          1.0                 0.0
# 3225                          0.0                 0.0
# ...

# %%
X_test_num_transformed = pd.DataFrame(scaler.transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 2200      -0.435476 -0.544091       -0.217375     -0.543516
# 4627      -0.435476  1.127890        1.731076      2.114680
# 3225      -0.435476 -0.788772        0.241378     -0.597262
# 2828      -0.435476 -1.278132       -1.476862     -0.997214
# 3768      -0.435476  0.923990        0.434889      0.882549

# %% [markdown]
# ## concating the scaled and encoded dataframes

# %%
X_test_transformed = pd.concat([X_test_num_transformed, X_test_cat_ohe], axis=1)

X_test_transformed.head()
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 2200      -0.435476 -0.544091       -0.217375     -0.543516          0.0
# 4627      -0.435476  1.127890        1.731076      2.114680          1.0
# 3225      -0.435476 -0.788772        0.241378     -0.597262          0.0
# 2828      -0.435476 -1.278132       -1.476862     -0.997214          1.0
# 3768      -0.435476  0.923990        0.434889      0.882549          0.0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 2200          0.0             0.0               1.0
# 4627          0.0             0.0               1.0
# 3225          0.0             0.0               1.0
# 2828          0.0             0.0               1.0
# 3768          1.0             0.0               1.0
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 2200                             0.0                0.0  ...
# 4627                             0.0                1.0  ...
# ...

# %% [markdown]
# ## logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
from sklearn import metrics

lg=metrics.accuracy_score(y_test, y_test_pred)
lg
# Out:
# 0.7967064168086314

# %% [markdown]
# ## KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

knn=metrics.accuracy_score(y_test, y_test_pred)
knn
# Out:
# 0.7490062464508802

# %% [markdown]
# ## Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

dt=metrics.accuracy_score(y_test, y_test_pred)
dt
# Out:
# 0.7410562180579217

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_transformed, y_train)

y_test_pred = classifier.predict(X_test_transformed)

rt=metrics.accuracy_score(y_test, y_test_pred)
rt
# Out:
# 0.7847813742191937

# %% [markdown]
# ## GBDT Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier()
classifier.fit(X_train_transformed, y_train)
y_test_pred = classifier.predict(X_test_transformed)
gbdt=metrics.accuracy_score(y_test, y_test_pred)
gbdt
# Out:
# 0.7847813742191937

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC
classifier = SVC()
classifier.fit(X_train_transformed, y_train)
# Out:
# SVC()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
sv=metrics.accuracy_score(y_test, y_test_pred)
sv
# Out:
# 0.7853492333901193

# %% [markdown]
# ## Gaussian NB Classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train_transformed,y_train)
y_test_pred = classifier.predict(X_test_transformed)
nb=metrics.accuracy_score(y_test, y_test_pred)
nb
# Out:
# 0.6740488358886996

# %% [markdown]
# ## dataframe

# %%
rows=[['Logistic Regression',lg],['SVC',sv],['DT classifier',dt],['KNN classifier',knn],['GaussianNB',nb],['Random forest Classifier',rt],['Gradient Boosting classifier',gbdt]]

df1=pd.DataFrame(data=rows,columns=['TYPE OF CLASSIFIER','Accuracy_Score'])

df1
# Out:
#              TYPE OF CLASSIFIER  Accuracy_Score
# 0           Logistic Regression        0.796706
# 1                           SVC        0.785349
# 2                 DT classifier        0.741056
# 3                KNN classifier        0.749006
# 4                    GaussianNB        0.674049
# 5      Random forest Classifier        0.784781
# 6  Gradient Boosting classifier        0.784781

# %% [markdown]
# ## observation

# %% [markdown]
# ## Logistic Regression is the best algorithm as it provides the highest accuracy in predicting the churn prediction
